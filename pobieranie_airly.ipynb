# %%
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize
url1 = 'https://airapi.airly.eu/v2/installations/nearest?lat=52.2326046&lng=20.7803207&maxDistanceKM=35&maxResults=-1'
url2 ='https://airapi.airly.eu/v2/measurements/installation?installationId=' 
apikey = '08x6sSF4ibdLggBLGrWS6TfpWIdVovPv'

# %%
req = requests.get(url1 + '&apikey=' + apikey,verify=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:843: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
json_text =req.json()
df = pd.io.json.json_normalize(json_text)

# %%
ids = df['id']
best_sensors=[]
for id in ids:
    test= requests.get(url2 +str(id)+ '&apikey=' + apikey,verify=False).json()
    try:
        cond = pd.io.json.json_normalize(test['history'][0]['values'])
        if len(cond) == 6:
            best_sensors.append(id)
    except:
        next
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:843: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:843: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:843: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
len(best_sensors)
len(ids)
# Out:
# 168

# %%
    test= requests.get(url2 +str(ids[1])+ '&apikey=' + apikey,verify=False).json()
    #cond = pd.io.json.json_normalize(test['history'][0]['values'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:843: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
pd.io.json.json_normalize(test['history'][0]['values'])
# Out:
#           name    value
# 0          PM1    35.60
# 1         PM25    58.60
# 2         PM10    89.46
# 3     PRESSURE  1012.87
# 4     HUMIDITY    84.53
# 5  TEMPERATURE     1.61
